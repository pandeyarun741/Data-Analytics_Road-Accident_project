# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Details_of_road_accident_deaths_by_situation_state_2014.csv')

# %%
df
# Out:
#              States/UTs  Year  \
# 0        Andhra Pradesh  2014
# 1        Andhra Pradesh  2014
# 2        Andhra Pradesh  2014
# 3        Andhra Pradesh  2014
# 4        Andhra Pradesh  2014
# ...                 ...   ...
# 1438  Total (All India)  2014
# 1439  Total (All India)  2014
# 1440  Total (All India)  2014
# 1441  Total (All India)  2014
# 1442  Total (All India)  2014
#
#                                               CrimeHead  \
# 0                                   Truck/Lorry (Total)
# 1                   Truck/Lorry - Normal Goods Carriers
# 2              Truck/Lorry - Trailer/Container Carriers
# 3                                 Truck/Lorry - Tankers
# 4                                  Truck/Lorry - Others
# ...                                                 ...
# 1438                               Animal Drawn Vehicle
# 1439                                         Pedestrian
# 1440                                             Others
# ...

# %%
df.head()
# Out:
#        States/UTs  Year                                 CrimeHead  \
# 0  Andhra Pradesh  2014                       Truck/Lorry (Total)
# 1  Andhra Pradesh  2014       Truck/Lorry - Normal Goods Carriers
# 2  Andhra Pradesh  2014  Truck/Lorry - Trailer/Container Carriers
# 3  Andhra Pradesh  2014                     Truck/Lorry - Tankers
# 4  Andhra Pradesh  2014                      Truck/Lorry - Others
#
#    Offenders (Driver/Pedestrian) Died_Male  \
# 0                                      445
# 1                                      357
# 2                                       12
# 3                                       10
# 4                                       66
#
#    Offenders (Driver/Pedestrian) Died_Female  \
# 0                                         30
# 1                                         25
# 2                                          0
# 3                                          0
# 4                                          5
#
# ...

# %%
df.columns
# Out:
# Index(['States/UTs', 'Year', 'CrimeHead',
#        'Offenders (Driver/Pedestrian) Died_Male',
#        'Offenders (Driver/Pedestrian) Died_Female',
#        'Offenders (Driver/Pedestrian) Died_Transgender',
#        'Offenders (Driver/Pedestrian) Died_Total', 'Victims Died_Male',
#        'Victims Died_Female', 'Victims Died_Transgender',
#        'Victims Died_Total'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              States/UTs  Year  \
# 0        Andhra Pradesh  2014
# 1        Andhra Pradesh  2014
# 2        Andhra Pradesh  2014
# 3        Andhra Pradesh  2014
# 4        Andhra Pradesh  2014
# ...                 ...   ...
# 1438  Total (All India)  2014
# 1439  Total (All India)  2014
# 1440  Total (All India)  2014
# 1441  Total (All India)  2014
# 1442  Total (All India)  2014
#
#                                               CrimeHead  \
# 0                                   Truck/Lorry (Total)
# 1                   Truck/Lorry - Normal Goods Carriers
# 2              Truck/Lorry - Trailer/Container Carriers
# 3                                 Truck/Lorry - Tankers
# 4                                  Truck/Lorry - Others
# ...                                                 ...
# 1438                               Animal Drawn Vehicle
# 1439                                         Pedestrian
# ...

# %%
df.describe(include=['object'])
# Out:
#             States/UTs            CrimeHead
# count             1443                 1443
# unique              39                   37
# top     Andhra Pradesh  Truck/Lorry (Total)
# freq                37                   39

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1443 entries, 0 to 1442
# Data columns (total 11 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   States/UTs                                      1443 non-null   object
#  1   Year                                            1443 non-null   int64
#  2   CrimeHead                                       1443 non-null   object
#  3   Offenders (Driver/Pedestrian) Died_Male         1443 non-null   int64
#  4   Offenders (Driver/Pedestrian) Died_Female       1443 non-null   int64
#  5   Offenders (Driver/Pedestrian) Died_Transgender  1443 non-null   int64
#  6   Offenders (Driver/Pedestrian) Died_Total        1443 non-null   int64
#  7   Victims Died_Male                               1443 non-null   int64
#  8   Victims Died_Female                             1443 non-null   int64
# ...

# %%
median=df['Year'].median()

# %%
median
# Out:
# 2014.0

# %%
mode= df['States/UTs'].mode

# %%
mode
# Out:
# <bound method Series.mode of 0          Andhra Pradesh
# 1          Andhra Pradesh
# 2          Andhra Pradesh
# 3          Andhra Pradesh
# 4          Andhra Pradesh
#               ...
# 1438    Total (All India)
# 1439    Total (All India)
# 1440    Total (All India)
# 1441    Total (All India)
# 1442    Total (All India)
# Name: States/UTs, Length: 1443, dtype: object>

# %%
offender_deaths = df[['Offenders (Driver/Pedestrian) Died_Male',
                      'Offenders (Driver/Pedestrian) Died_Female',
                      'Offenders (Driver/Pedestrian) Died_Transgender',
                      'Offenders (Driver/Pedestrian) Died_Total']].sum()
victim_deaths = df[['Victims Died_Male',
                    'Victims Died_Female', 
                    'Victims Died_Transgender',
                    'Victims Died_Total']].sum()
summary = pd.DataFrame({
    'Offenders': offender_deaths,
    'Victims': victim_deaths
}).transpose()
summary[['Offenders (Driver/Pedestrian) Died_Male',
         'Offenders (Driver/Pedestrian) Died_Female',
         'Offenders (Driver/Pedestrian) Died_Transgender']].plot(kind='bar', stacked=True)

plt.title('Deaths by Gender (Offenders)')
plt.ylabel('Number of Deaths')
plt.show()

summary[['Victims Died_Male',
         'Victims Died_Female',
         'Victims Died_Transgender']].plot(kind='bar', stacked=True)
plt.title('Deaths by Gender (Victims)')
plt.ylabel('Number of Deaths')
plt.show()


summary[['Offenders (Driver/Pedestrian) Died_Total',
         'Victims Died_Total']].plot(kind='bar', color=['blue', 'orange'])

plt.title('Total Deaths (Offenders vs Victims)')
plt.ylabel('Total Deaths')
plt.show()

# %%
total_accidents_by_state = df.groupby('States/UTs').agg({
    'Offenders (Driver/Pedestrian) Died_Total': 'sum',
    'Victims Died_Total': 'sum',
    'Victims Died_Male':'sum',
    'Victims Died_Female':'sum',
    
}).reset_index()


total_accidents_by_state['Total_Accidents'] = total_accidents_by_state['Offenders (Driver/Pedestrian) Died_Total'] + total_accidents_by_state['Victims Died_Total']


total_accidents_by_state
# Out:
#            States/UTs  Offenders (Driver/Pedestrian) Died_Total  \
# 0       A & N Islands                                        32
# 1      Andhra Pradesh                                      8427
# 2   Arunachal Pradesh                                       234
# 3               Assam                                      1863
# 4               Bihar                                      3024
# 5          Chandigarh                                        19
# 6        Chhattisgarh                                      5303
# 7          D&N Haveli                                       174
# 8         Daman & Diu                                         0
# 9            Delhi UT                                       229
# 10                Goa                                       320
# 11            Gujarat                                      6877
# 12            Haryana                                       889
# 13   Himachal Pradesh                                      1752
# ...

# %%
States_highest_No_accidents = total_accidents_by_state.loc[total_accidents_by_state['Total_Accidents'].idxmax()]

States_highest_No_accidents
# Out:
# States/UTs                                  Total (All India)
# Offenders (Driver/Pedestrian) Died_Total               131462
# Victims Died_Total                                     406255
# Victims Died_Male                                      339525
# Victims Died_Female                                     66665
# Total_Accidents                                        537717
# Name: 32, dtype: object

# %%
gender_deaths = df.groupby('States/UTs').agg({
    'Offenders (Driver/Pedestrian) Died_Total': 'sum',
    'Victims Died_Total': 'sum',
    'Victims Died_Male':'sum',
    'Victims Died_Female':'sum',
    'Victims Died_Transgender':'sum',
    'Offenders (Driver/Pedestrian) Died_Male':'sum',
    'Offenders (Driver/Pedestrian) Died_Female':'sum',
    'Offenders (Driver/Pedestrian) Died_Transgender':'sum',
    
}).reset_index()

# %%
gender_deaths['Total_Deaths'] = gender_deaths['Offenders (Driver/Pedestrian) Died_Total'] + gender_deaths['Victims Died_Total']

gender_deaths
# Out:
#            States/UTs  Offenders (Driver/Pedestrian) Died_Total  \
# 0       A & N Islands                                        32
# 1      Andhra Pradesh                                      8427
# 2   Arunachal Pradesh                                       234
# 3               Assam                                      1863
# 4               Bihar                                      3024
# 5          Chandigarh                                        19
# 6        Chhattisgarh                                      5303
# 7          D&N Haveli                                       174
# 8         Daman & Diu                                         0
# 9            Delhi UT                                       229
# 10                Goa                                       320
# 11            Gujarat                                      6877
# 12            Haryana                                       889
# 13   Himachal Pradesh                                      1752
# ...
